# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.cluster.hierarchy as sch
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
airline=pd.read_excel("EastWestAirlines.xlsx", sheet_name='data')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airline=airline.iloc[:,1:]
Airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
 #### Heirarchical clustering

# %%
sns.distplot(Airline.Balance)
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='Density'>

# %%
sns.distplot(Airline.Qual_miles)
# Out:
# <AxesSubplot:xlabel='Qual_miles', ylabel='Density'>

# %%
### Normalization Function

# %%
def minmax_func(i):
    x =(i-i.min())/(i.max()-i.min())
    return(x)

# %%
df_norm = minmax_func(Airline.iloc[:,:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
## Creating Dendrogram

# %%
dendrogram =sch.dendrogram(sch.linkage(df_norm, method='single'))

# %%
dendrogram =sch.dendrogram(sch.linkage(df_norm, method='centroid'))

# %%
dendrogram =sch.dendrogram(sch.linkage(df_norm, method='average'))

# %%
dendrogram =sch.dendrogram(sch.linkage(df_norm, method='complete'))

# %%
### creating clusters

# %%
hc = AgglomerativeClustering(n_clusters=8, affinity = 'euclidean',linkage = 'complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=8)

# %%
y_hc =hc.fit_predict(df_norm)
y_hc
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
Airline['h_clusterid']=y_hc
Airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline[Airline['h_clusterid']==0]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7       20856           0          1          1          1         5250
# 8      443003           0          3          2          1         1753
# 9      104860           0          3          1          1        28426
# 17      13958           0          1          1          1         4291
# 18      91473           0          3          1          1        27408
# ...       ...         ...        ...        ...        ...          ...
# 3987    11933           0          1          1          1          249
# 3989     2622           0          1          1          1         1625
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline[Airline['h_clusterid']==1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4       97752           0          4          1          1        43300
# 11      96522           0          5          1          1        61105
# 15      28495           0          4          1          1        49442
# 16      51890           0          4          1          1        48963
# 20     120576           0          5          1          1        58831
# ...       ...         ...        ...        ...        ...          ...
# 3753    70178           0          5          1          1        61530
# 3772   822321           0          5          1          1       138334
# 3846    97510        1678          5          1          1        71609
# 3855   190730           0          5          1          1        78916
# 3883   126167           0          5          1          1       190160
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline[Airline['h_clusterid']==2]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 5       16420           0          1          1          1            0
# ...       ...         ...        ...        ...        ...          ...
# 3990    11310           0          1          1          1         5021
# 3992    11181           0          1          1          1          929
# 3993     3974           0          1          1          1          365
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline[Airline['h_clusterid']==3]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 32     276571           0          4          1          1        42044
# 56      75971           0          4          1          1        34339
# 67      83237           0          4          1          1        35287
# 71     252386           0          4          1          1        39787
# 77     111157           0          4          1          1        32883
# ...       ...         ...        ...        ...        ...          ...
# 3972    35185           0          2          1          1         5957
# 3974    58387           0          3          1          1        14581
# 3980    28867           0          3          1          1        19169
# 3985    59017           0          4          1          1        34746
# 3991    39142           0          3          1          1        14981
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline[Airline['h_clusterid']==4]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 198      8669           0          1          3          1        11397
# 381    167670           0          1          3          1        15907
# 794     55610           0          1          2          1         5095
# 940     44824           0          1          3          1        21107
# 1149    84856           0          1          2          1         6894
# 1270    16103           0          1          3          1        10819
# 1389    49145           0          1          2          1        12755
# 1527    23965           0          1          2          1         7308
# 1541    36887           0          1          2          1         9048
# 1791    32510           0          1          3          1        14568
# 1918    52139           0          1          3          1        16314
# 1976    11961           0          1          2          1        11961
# ...

# %%
Airline[Airline['h_clusterid']==5]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 106     96627        1182          1          1          3        49059
# 904     15835           0          2          1          5       112171
# 2955    61474           0          1          1          4        47717
# 3338    84148           0          1          1          5        84148
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 106            26               2300                9               6738
# 904            16                  0                0               5825
# 2955           14                  0                0               3354
# 3338            7                  0                0               1054
#
#       Award?  h_clusterid
# 106        1            5
# 904        1            5
# 2955       0            5
# 3338       0            5

# %%
Airline[Airline['h_clusterid']==6]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 335    278457        6727          4          1          1        57313
# 901    172110        9325          5          1          1        21382
# 1177    32214       11148          3          1          1        12717
# 1337   128664        8019          4          1          1        44298
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 335            27               1000                2               7101
# 901            23                950                3               5944
# 1177           10                  0                0               5576
# 1337           16                 50                1               5155
#
#       Award?  h_clusterid
# 335        1            6
# 901        1            6
# 1177       1            6
# 1337       1            6

# %%
Airline[Airline['h_clusterid']==7]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2015    53232         888          4          1          1        80696
# 3235   287033           0          1          1          1        26161
# 3583   160114         500          1          1          1        71954
# 3594    27619           0          4          1          1        83726
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2015           65              22100               45               3831
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
# 3594           68              14050               46               1325
#
#       Award?  h_clusterid
# 2015       1            7
# 3235       1            7
# 3583       1            7
# 3594       1            7

# %%
Airline.groupby('h_clusterid').mean()
# Out:
#                    Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# h_clusterid
# 0             79918.920175   218.528947   2.098246   1.009649   1.000877
# 1            157084.578462   208.673846   4.661538   1.000000   1.061538
# 2             45074.547804    90.659432   1.187080   1.000000   1.000517
# 3            111769.618705    81.217626   3.543165   1.001799   1.025180
# 4             45515.064516    32.258065   1.000000   2.483871   1.000000
# 5             64521.000000   295.500000   1.250000   1.000000   4.250000
# 6            152861.250000  8804.750000   4.000000   1.000000   1.000000
# 7            131999.500000   347.000000   2.500000   1.000000   1.000000
#
#               Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# h_clusterid
# 0            16823.058772    13.392982         740.800877         2.239474
# 1            70477.086154    23.249231        1019.433846         3.196923
# ...

# %%
### KMeans Clustering

# %%
airline1=pd.read_excel("EastWestAirlines.xlsx", sheet_name='data')
airline1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airline1=airline1.iloc[:,1:]
Airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
###  Similar to the sklearn.preprocessing, MinMaxScaler function

# %%
def minmax_func(i):
    X = (i-i.min())/(i.max()-i.min())
    return (X)

# %%
###  Similar to the sklearn.preprocessing, StandardScaler function

# %%
def norm_func(i):
    X = (i-i.mean())/(i.std())
    return (X)

# %%
x=norm_func(Airline1.iloc[:,:])
x
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451084   -0.186275  -0.769482   -0.09823  -0.062759    -0.702698
# 1    -0.539389   -0.186275  -0.769482   -0.09823  -0.062759    -0.701001
# 2    -0.319991   -0.186275  -0.769482   -0.09823  -0.062759    -0.539185
# 3    -0.583726   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 4     0.239648   -0.186275   1.409295   -0.09823  -0.062759     1.082986
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547010   -0.186275  -0.769482   -0.09823  -0.062759    -0.356915
# 3995 -0.091454   -0.186275  -0.769482   -0.09823  -0.062759    -0.669284
# 3996 -0.000043   -0.186275   0.683036   -0.09823  -0.062759     0.343761
# 3997 -0.185584   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 3998 -0.700420   -0.186275  -0.769482   -0.09823  -0.062759    -0.709903
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
### Normalization Function

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_Airline1_df = scaler.fit_transform(Airline1.iloc[:,:])

# %%
scaled_Airline1_df
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
## Now we use WCSS to find K Value for Clusters

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

print(wcss)    
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# [43978.00000000041, 35400.65686091362, 30891.520081260187, 27439.5091477401, 24535.192715433746, 21084.699817069686, 19161.068795125357, 17312.53614694215, 16039.394387785456, 14723.300656269628]

# %%
### Building Clustering  algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(6,random_state=0)
clusters_new.fit(x)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
clusters_new.labels_
# Out:
# array([2, 2, 2, ..., 1, 2, 2])

# %%
Airline1['clusterid_new'] = clusters_new.labels_
Airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
### Standardized Cluster Values

# %%
clusters_new.cluster_centers_
# Out:
# array([[ 1.13672618,  0.4142095 ,  0.13453248, -0.0982296 , -0.06275873,
#          0.6563188 ,  1.70527321,  3.7706056 ,  4.00162516,  0.27150403,
#          0.88384759],
#        [ 0.43375859, -0.11299849,  1.20999847, -0.0982296 , -0.05449097,
#          0.92801911,  0.75259721, -0.0806481 , -0.08955435,  0.37074737,
#          0.57846773],
#        [-0.29441039, -0.12881844, -0.60143667, -0.0982296 , -0.06070834,
#         -0.51676295, -0.49343019, -0.18633934, -0.19843461, -0.19788593,
#         -0.34988946],
#        [-0.0468838 , -0.15621606, -0.66814372,  9.03712348, -0.06275873,
#         -0.10165261,  0.61777389,  0.08753845,  0.22031926, -0.07245492,
#          0.05177741],
#        [ 0.63963927, -0.08442237,  1.0219566 , -0.0982296 , 15.64434291,
#          3.17929372,  1.71439935,  0.03328853,  0.05968793,  0.23984262,
#          0.33748514],
#        [ 0.45704649,  6.73025029, -0.04322321, -0.0982296 , -0.06275873,
# ...

# %%
Airline1.groupby('clusterid_new').agg(['mean']).reset_index()
# Out:
#   clusterid_new        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                           mean         mean      mean      mean      mean
# 0             0  188155.664336   464.573427  2.244755  1.000000  1.000000
# 1             1  117176.916331    58.446500  3.720837  1.000000  1.001609
# 2             2   43882.372895    43.558140  1.229751  1.000000  1.000401
# 3             3   68876.581395    23.255814  1.139535  2.348837  1.000000
# 4             4  138061.400000    78.800000  3.466667  1.000000  4.066667
# 5             5  119660.491803  5351.065574  2.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  32995.580420   27.979021       5739.692308       16.552448
# 1  39485.872084   18.811746        346.617860        1.032180
# 2   4644.210104    6.852847        199.160385        0.621091
# 3  14689.837209   17.534884        582.627907        2.209302
# ...

# %%
Airline1['clusterid_new'].value_counts()
# Out:
# 2    2494
# 1    1243
# 0     143
# 5      61
# 3      43
# 4      15
# Name: clusterid_new, dtype: int64

# %%
## DBSCAN  Clustering Method

# %%
airline2=pd.read_excel("EastWestAirlines.xlsx", sheet_name='data')
airline2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airline2=airline2.iloc[:,1:]
Airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
array=Airline2.values

# %%
array
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]], dtype=int64)

# %%
stscaler = StandardScaler().fit(array)
y = stscaler.transform(array)

# %%
y
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan =DBSCAN(eps=1.9,min_samples=7)
dbscan.fit(y)
# Out:
# DBSCAN(eps=1.9, min_samples=7)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
Airline2['cluster']=pd.DataFrame(dbscan.labels_)
Airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airline2['cluster'].value_counts()
# Out:
#  0    2441
#  1    1301
# -1     232
#  2      16
#  3       9
# Name: cluster, dtype: int64

# %%
#### The value -1 is a noisy aka outliers

# %%
## Finding Percentage  of noise points

# %%
(len(Airline2[Airline2['cluster']==-1])/len(Airline2))*100
# Out:
# 5.801450362590647

# %%
y=metrics.silhouette_score(y,dbscan.labels_)
y
# Out:
# 0.2587893508617342

# %%
def dbscan(y,eps,min_samples):
    ss=StandardScaler()
    y=ss.fit_transform(y)
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(y)
    y_pred=db.fit_predict(y)
    plt.scatter(y[:,0],y[:,1],c=y_pred, cmap='Paired')
    plt.title("DBSCAN")

# %%
dbscan(array,1.9,7)
